# %%
import pandas as pd
import numpy as np
url = 'https://raw.githubusercontent.com/ACM-Amrita-Amritapuri/AI-Daily-Tasks/main/Data%20Pre-Processing%20(8-11-22)/Data_Set.csv'
df1 = pd.read_csv(url)

# %%
#firest 10 rows
result = df1.head(10)

# %%
#total null values
df1.isna()
# Out:
#          SNo  ObservationDate  Province/State  Country/Region  Last Update  \
# 0      False            False           False           False        False
# 1      False            False           False           False        False
# 2      False            False           False           False        False
# 3      False            False           False           False        False
# 4      False            False           False           False        False
# ...      ...              ...             ...             ...          ...
# 10666  False            False           False           False        False
# 10667  False            False           False           False        False
# 10668  False            False           False           False        False
# 10669  False            False           False           False        False
# 10670  False            False           False           False        False
#
#        Confirmed  Deaths  Recovered
# ...

# %%
#check total features and summary
df1.info()
df1.info(verbose = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10671 entries, 0 to 10670
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SNo              10671 non-null  int64
#  1   ObservationDate  10671 non-null  object
#  2   Province/State   5715 non-null   object
#  3   Country/Region   10671 non-null  object
#  4   Last Update      10671 non-null  object
#  5   Confirmed        10671 non-null  float64
#  6   Deaths           10671 non-null  float64
#  7   Recovered        10671 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 667.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10671 entries, 0 to 10670
# Columns: 8 entries, SNo to Recovered
# dtypes: float64(3), int64(1), object(4)
# memory usage: 667.1+ KB

# %%
df1.dtypes
# Out:
# SNo                  int64
# ObservationDate     object
# Province/State      object
# Country/Region      object
# Last Update         object
# Confirmed          float64
# Deaths             float64
# Recovered          float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

for col in df1.columns:
    if df1[col].dtype == 'object':
        df1[col] = LabelEncoder().fit_transform(df1[col])
df1.describe()
# Out:
#                 SNo  ObservationDate  Province/State  Country/Region  \
# count  10671.000000     10671.000000    10671.000000    10671.000000
# mean    5336.000000        46.817543      215.773405      126.291350
# std     3080.596695        17.674161       93.722930       62.908409
# min        1.000000         0.000000        0.000000        0.000000
# 25%     2668.500000        37.000000      132.000000       80.000000
# 50%     5336.000000        51.000000      276.000000      122.000000
# 75%     8003.500000        61.000000      293.000000      197.000000
# max    10671.000000        69.000000      293.000000      214.000000
#
#         Last Update      Confirmed        Deaths     Recovered
# count  10671.000000   10671.000000  10671.000000  10671.000000
# mean    1184.258270     993.821666     40.667229    289.508481
# std      619.354947    6268.835379    398.618024   3010.809184
# min        0.000000       0.000000      0.000000      0.000000
# ...

# %%
#DISPLAYED NORMAL HEATMAP FOR NOW..WILL MAKECHANGES LATER.
import matplotlib.pyplot as mp
import pandas as pd
import seaborn as sb
mp.figure(figsize = (15, 15))
sb.heatmap(df1.corr(), annot = True)
mp.show()

# %%
print('Target variable = Confirmed')
# Out:
# Target variable = Confirmed

# %%
sb.pairplot(df1)

# %%
mp.scatter(df1.Confirmed, df1.Deaths)
